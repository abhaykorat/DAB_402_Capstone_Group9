# %%
# Importing all libraries from other file

# %run Libraries.ipynb

# %%
# Loading dataset
Before_Pandemic = pd.read_csv('Before_Pandemic.csv')

During_Pandemic = pd.read_csv('During_Pandemic.csv')

# %% [markdown]
# ### Data Transformation

# %% [markdown]
# #### 1. "Before_Pandemic" dataset:

# %%
# Renaming features name for better understanding

Before_Pandemic1 = Before_Pandemic.rename(columns={'Labour force characteristics': 'Labour_characteristics', 'North American Industry Classification System (NAICS)':'NAICS'})
Before_Pandemic1 = Before_Pandemic1.replace('Full-time employment','Full-time').replace('Part-time employment','Part-time')

Before_Pandemic1
# Out:
#        REF_DATE               GEO Labour_characteristics  \
# 0          2017            Canada           Labour force
# 1          2017            Canada           Labour force
# 2          2017            Canada           Labour force
# 3          2017            Canada           Labour force
# 4          2017            Canada           Labour force
# ...         ...               ...                    ...
# 42360      2019  British Columbia           Unemployment
# 42361      2019  British Columbia           Unemployment
# 42362      2019  British Columbia           Unemployment
# 42363      2019  British Columbia           Unemployment
# 42364      2019  British Columbia           Unemployment
#
#                          NAICS         Sex          Age group    VALUE
# 0        Total, all industries  Both sexes  15 years and over  19530.3
# 1        Total, all industries  Both sexes     15 to 24 years   2829.8
# ...

# %%
# Using ordinal encoding for categorical variables 'Labour_characteristics', 'Sex', & 'Age group'

Ordinal_encoder = ce.OrdinalEncoder(mapping=[{'col':'Labour_characteristics', 'mapping':{'Unemployment':0, 'Employment':1, 'Full-time':2, 'Labour force':3, 'Part-time':4}},
                                                 {'col':'Sex', 'mapping':{'Both sexes':0, 'Males':1, 'Females':2}},
                                                 {'col':'Age group', 'mapping':{'15 years and over':0, '15 to 24 years':1, '25 to 54 years':2, '55 years and over':3}}])

Ordinal_encoder.fit(Before_Pandemic1)
Before_Pandemic1 = Ordinal_encoder.transform(Before_Pandemic1)

Before_Pandemic1
# Out:
#        REF_DATE               GEO  Labour_characteristics  \
# 0          2017            Canada                       3
# 1          2017            Canada                       3
# 2          2017            Canada                       3
# 3          2017            Canada                       3
# 4          2017            Canada                       3
# ...         ...               ...                     ...
# 42360      2019  British Columbia                       0
# 42361      2019  British Columbia                       0
# 42362      2019  British Columbia                       0
# 42363      2019  British Columbia                       0
# 42364      2019  British Columbia                       0
#
#                          NAICS  Sex  Age group    VALUE
# 0        Total, all industries    0          0  19530.3
# 1        Total, all industries    0          1   2829.8
# 2        Total, all industries    0          2  12634.6
# ...

# %%
# Using label encoding for categorical variables 'GEO', 'NAICS'


# Changing datatypes of 'GEO' & 'NAICS' variables to category from object
Before_Pandemic1['GEO'] = Before_Pandemic1['GEO'].astype('category')
Before_Pandemic1['NAICS'] = Before_Pandemic1['NAICS'].astype('category')

# Creating an instance of labelencoder
labelencoder = LabelEncoder()


# Assigning numerical values and storing in another column
Before_Pandemic1['GEO_Cat'] = labelencoder.fit_transform(Before_Pandemic1['GEO'])
Before_Pandemic1['NAICS_Cat'] = labelencoder.fit_transform(Before_Pandemic1['NAICS'])

Before_Pandemic1
# Out:
#        REF_DATE               GEO  Labour_characteristics  \
# 0          2017            Canada                       3
# 1          2017            Canada                       3
# 2          2017            Canada                       3
# 3          2017            Canada                       3
# 4          2017            Canada                       3
# ...         ...               ...                     ...
# 42360      2019  British Columbia                       0
# 42361      2019  British Columbia                       0
# 42362      2019  British Columbia                       0
# 42363      2019  British Columbia                       0
# 42364      2019  British Columbia                       0
#
#                          NAICS  Sex  Age group    VALUE  GEO_Cat  NAICS_Cat
# 0        Total, all industries    0          0  19530.3        2         23
# 1        Total, all industries    0          1   2829.8        2         23
# ...

# %%
# Creating temporary variable to check assigned numeric values by lable encoding

d1 = Before_Pandemic1[["GEO", "GEO_Cat"]]
d2 = Before_Pandemic1[["NAICS", "NAICS_Cat"]]

# %%
# Printing assigned numeric values

d1.drop_duplicates('GEO')
d2.drop_duplicates('NAICS')
# Out:
#                                                  NAICS  NAICS_Cat
# 0                                Total, all industries         23
# 12                              Goods-producing sector         11
# 24              Agriculture [111-112, 1100, 1151-1152]          1
# 36   Forestry, fishing, mining, quarrying, oil and ...         10
# 48   Forestry and logging and support activities fo...          9
# 59                 Fishing, hunting and trapping [114]          8
# 69   Mining, quarrying, and oil and gas extraction ...         15
# 81                                      Utilities [22]         26
# 93                                   Construction [23]          3
# 105                              Manufacturing [31-33]         14
# 117                       Durables [321, 327, 331-339]          4
# 129                    Non-durables [311-316, 322-326]         16
# 141                          Services-producing sector         22
# ...

# %% [markdown]
# #### 2. "During_Pandemic" dataset:

# %%
# Renaming features name for better understanding

During_Pandemic1 = During_Pandemic.rename(columns={'Labour force characteristics': 'Labour_characteristics', 'North American Industry Classification System (NAICS)':'NAICS'})
During_Pandemic1 = During_Pandemic1.replace('Full-time employment','Full-time').replace('Part-time employment','Part-time')

During_Pandemic1
# Out:
#        REF_DATE               GEO Labour_characteristics  \
# 0          2020            Canada           Labour force
# 1          2020            Canada           Labour force
# 2          2020            Canada           Labour force
# 3          2020            Canada           Labour force
# 4          2020            Canada           Labour force
# ...         ...               ...                    ...
# 28619      2021  British Columbia           Unemployment
# 28620      2021  British Columbia           Unemployment
# 28621      2021  British Columbia           Unemployment
# 28622      2021  British Columbia           Unemployment
# 28623      2021  British Columbia           Unemployment
#
#                          NAICS         Sex          Age group    VALUE
# 0        Total, all industries  Both sexes  15 years and over  19896.6
# 1        Total, all industries  Both sexes     15 to 24 years   2775.5
# ...

# %%
# Using ordinal encoding for categorical variables 'Labour_characteristics', 'Sex', & 'Age group'

Ordinal_encoder = ce.OrdinalEncoder(mapping=[{'col':'Labour_characteristics', 'mapping':{'Unemployment':0, 'Employment':1, 'Full-time':2, 'Labour force':3, 'Part-time':4}},
                                                 {'col':'Sex', 'mapping':{'Both sexes':0, 'Males':1, 'Females':2}},
                                                 {'col':'Age group', 'mapping':{'15 years and over':0, '15 to 24 years':1, '25 to 54 years':2, '55 years and over':3}}])

Ordinal_encoder.fit(During_Pandemic1)
During_Pandemic1 = Ordinal_encoder.transform(During_Pandemic1)

During_Pandemic1
# Out:
#        REF_DATE               GEO  Labour_characteristics  \
# 0          2020            Canada                       3
# 1          2020            Canada                       3
# 2          2020            Canada                       3
# 3          2020            Canada                       3
# 4          2020            Canada                       3
# ...         ...               ...                     ...
# 28619      2021  British Columbia                       0
# 28620      2021  British Columbia                       0
# 28621      2021  British Columbia                       0
# 28622      2021  British Columbia                       0
# 28623      2021  British Columbia                       0
#
#                          NAICS  Sex  Age group    VALUE
# 0        Total, all industries    0          0  19896.6
# 1        Total, all industries    0          1   2775.5
# 2        Total, all industries    0          2  12807.8
# ...

# %%
# Using label encoding for categorical variables 'GEO', 'NAICS'

# Changing datatypes of 'GEO' & 'NAICS' variables to category from object
During_Pandemic1['GEO'] = During_Pandemic1['GEO'].astype('category')
During_Pandemic1['NAICS'] = During_Pandemic1['NAICS'].astype('category')

# Creating an instance of labelencoder
labelencoder = LabelEncoder()


# Assigning numerical values and storing in another column
During_Pandemic1['GEO_Cat'] = labelencoder.fit_transform(During_Pandemic1['GEO'])
During_Pandemic1['NAICS_Cat'] = labelencoder.fit_transform(During_Pandemic1['NAICS'])

During_Pandemic1
# Out:
#        REF_DATE               GEO  Labour_characteristics  \
# 0          2020            Canada                       3
# 1          2020            Canada                       3
# 2          2020            Canada                       3
# 3          2020            Canada                       3
# 4          2020            Canada                       3
# ...         ...               ...                     ...
# 28619      2021  British Columbia                       0
# 28620      2021  British Columbia                       0
# 28621      2021  British Columbia                       0
# 28622      2021  British Columbia                       0
# 28623      2021  British Columbia                       0
#
#                          NAICS  Sex  Age group    VALUE  GEO_Cat  NAICS_Cat
# 0        Total, all industries    0          0  19896.6        2         23
# 1        Total, all industries    0          1   2775.5        2         23
# ...

# %%
# Creating temporary variable to check assigned numeric values by lable encoding

d3 = During_Pandemic1[["GEO", "GEO_Cat"]]
d4 = During_Pandemic1[["NAICS", "NAICS_Cat"]]

# %%
# Printing assigned numeric values

d3.drop_duplicates("GEO")
d4.drop_duplicates('NAICS')
# Out:
#                                                  NAICS  NAICS_Cat
# 0                                Total, all industries         23
# 12                              Goods-producing sector         11
# 24              Agriculture [111-112, 1100, 1151-1152]          1
# 36   Forestry, fishing, mining, quarrying, oil and ...         10
# 48   Forestry and logging and support activities fo...          9
# 60                 Fishing, hunting and trapping [114]          8
# 71   Mining, quarrying, and oil and gas extraction ...         15
# 83                                      Utilities [22]         26
# 95                                   Construction [23]          3
# 107                              Manufacturing [31-33]         14
# 119                       Durables [321, 327, 331-339]          4
# 131                    Non-durables [311-316, 322-326]         16
# 143                          Services-producing sector         22
# ...

# %%
Before_Pandemic1.set_index('REF_DATE', inplace=True)

During_Pandemic1.set_index('REF_DATE', inplace=True)

# %%
# Saving files

Before_Pandemic1.to_csv('C:/Users/Kuldeep/OneDrive/Desktop/DAB402/Before_Pandemic1.csv')

During_Pandemic1.to_csv('C:/Users/Kuldeep/OneDrive/Desktop/DAB402/During_Pandemic1.csv')

# %% [markdown]
# ### Performing 'Pandas-Profiling' for the better understanding

# %% [markdown]
# #### Before-Pandemic dataset

# %%
df = pd.DataFrame(Before_Pandemic1, columns=["GEO_Cat", "Labour_characteristics", "NAICS_Cat", "Sex", "Age group", "VALUE"])

# %%
profile = ProfileReport(df, title="Pandas Profiling Report")

# %%
profile.to_widgets()
# Out:
# ...
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %%
profile.to_file("your_report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# #### During-Pandemic dataset

# %%
df1 = pd.DataFrame(During_Pandemic1, columns=["GEO_Cat", "Labour_characteristics", "NAICS_Cat", "Sex", "Age group", "VALUE"])

# %%
profile1 = ProfileReport(df1, title="Pandas Profiling Report")
profile1.to_widgets()
# Out:
# ...
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %%
profile1.to_file("your_report1.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
